# %%
import pandas as pd

# %%
pd.reset_option('max_columns')
pd.reset_option('max_rows')

# %%
df = pd.read_csv('/home/sid2018-4/Documents/M2 SID/pip2022/ProjectInterPromo/data/DONNEES_CONCAT_TLSE-LD/DATA1_COMPLET.csv')
# Out:
# /home/sid2018-4/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#                                  ID  TOP_FRAUDE  TOP_FRAUDE_CARTE  \
# 0       8312v5IodTRgOR8/FWWjGEwsg==           0                 0
# 1       831pI3Dnm1zz6NG0iCJTfcilQ==           0                 0
# 2       831b9S86qzWBJCaqgYOVPwWMQ==           0                 0
# 3       831tT9jw5y/rwwLEMZF7PyE8w==           0                 0
# 4       8317VwmuKeVaijtrz0cTWOm4A==           0                 0
# ...                             ...         ...               ...
# 849341  835mBEOByTBamgQVgQg771KDA==           1                 1
# 849342  835rWBxack6OQY9AQFqyqJd5g==           1                 1
# 849343  835F1MFghZuFjdn+sBHNuQaBw==           1                 1
# 849344  835HAiChYU6Al85Ed4c5I/urw==           1                 1
# 849345  835g8FUcHQCK+Bn93a9y9Ko7w==           1                 0
#
#         TOP_FRAUDE_VIREMENT Date_debut_fraude cp_ou_pays  \
# 0                         0         01FEB2021      fìPÅæ
# ...

# %%
print(df.isna().sum())
# Out:
# ID                          0
# TOP_FRAUDE                  0
# TOP_FRAUDE_CARTE            0
# TOP_FRAUDE_VIREMENT         0
# Date_debut_fraude      584053
#                         ...
# mt_rist_ttc_M6          99908
# Fidelite_calcule         3058
# Flag_bq_principale       3058
# profil                    150
# localisation                0
# Length: 288, dtype: int64

# %%
df.dtypes
# Out:
# ID                      object
# TOP_FRAUDE               int64
# TOP_FRAUDE_CARTE         int64
# TOP_FRAUDE_VIREMENT      int64
# Date_debut_fraude       object
#                         ...
# mt_rist_ttc_M6         float64
# Fidelite_calcule        object
# Flag_bq_principale     float64
# profil                  object
# localisation            object
# Length: 288, dtype: object

# %%
df[['sexe_1', 'sexe_2']]
# Out:
#        sexe_1 sexe_2
# 0           M    NaN
# 1           M      F
# 2           M    NaN
# 3           F      M
# 4           F      M
# ...       ...    ...
# 849341      M    NaN
# 849342      M      F
# 849343      F    NaN
# 849344      M    NaN
# 849345      M      F
#
# [849346 rows x 2 columns]

# %%
df[['contrat_travail_1', 'contrat_travail_2']]
# Out:
#                    contrat_travail_1             contrat_travail_2
# 0                            INCONNU                           NaN
# 1       CONTRAT A DUREE INDETERMINEE  CONTRAT A DUREE INDETERMINEE
# 2                            INCONNU                           NaN
# 3       CONTRAT A DUREE INDETERMINEE                       INCONNU
# 4       CONTRAT A DUREE INDETERMINEE  CONTRAT A DUREE INDETERMINEE
# ...                              ...                           ...
# 849341                       INCONNU                           NaN
# 849342                       INCONNU                       INCONNU
# 849343  CONTRAT A DUREE INDETERMINEE                           NaN
# 849344                       INCONNU                           NaN
# 849345    CONTRAT A DUREE DETERMINEE    CONTRAT A DUREE DETERMINEE
#
# [849346 rows x 2 columns]
