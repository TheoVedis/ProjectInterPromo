# %%
import pandas as pd
import numpy as np
import zipfile
import matplotlib.pyplot as plt
import sweetviz as sv

# %%
PROJECT_PATH = "C:/Users/USER/OneDrive/Bureau/ProjectInterPromo/"

# %%
data_v1 = pd.read_csv(PROJECT_PATH +"data/Donnees_v1.csv")

# %%
Colonnes_momo = ['NB_JR_MBANQUE_6M',
 'NB_DEVIS_PACIFICA_AG_6M',
 'MONETAIRE_DISPONIBLE',
 'nb_operation_credit_depot_M',
 'SURFACE_FINANCIERE_M6',
 'nb_ret_carte_Aut_bq_M',
 'NB_VIR_AGENCE_6M',
 'nb_operation_debit_ep_a_vue_M6',
 'mt_ret_carte_etr_M6',
 'SURFACE_FINANCIERE_ECART_M6',
 'ENCOURS_CONSO',
 'mt_paiement_carte_M',
 'mt_ret_carte_CRCA_M6',
 'mt_op_debit_ep_a_terme_M6',
 'NB_VEL_PACIFICA_6M',
 'NB_MAIL_LU_6M',
 'TAUX_LECTURE_PAP_6M',
 'nb_pmts_carte_etr_M',
 'ALERTE_SMS_6M',
 'qt_oblig']
data_momo=data_v1[Colonnes_momo]

# %%
data_momo
# Out:
#         NB_JR_MBANQUE_6M  NB_DEVIS_PACIFICA_AG_6M  MONETAIRE_DISPONIBLE  \
# 0                    0.0                      0.0                   0.0
# 1                  165.0                      0.0                  56.0
# 2                   36.0                      0.0                1300.0
# 3                  149.0                      4.0                1800.0
# 4                   42.0                      0.0               15400.0
# ...                  ...                      ...                   ...
# 849407             121.0                      6.0                 310.0
# 849408             107.0                      0.0                   0.0
# 849409               3.0                      2.0                4000.0
# 849410              62.0                      0.0                   0.0
# 849411               0.0                      0.0                   0.0
#
#         nb_operation_credit_depot_M  SURFACE_FINANCIERE_M6  \
# ...

# %%
def analyse(df):
    for i in df.columns:
        print(f'la variance de la variable {str(i)} est {np.var(df[str(i)])}')

# %%
analyse(data_momo)
# Out:
# la variance de la variable NB_JR_MBANQUE_6M est 1952.8955251085176
# la variance de la variable NB_DEVIS_PACIFICA_AG_6M est 0.3935205121436187
# la variance de la variable MONETAIRE_DISPONIBLE est 1197241244.1108027
# la variance de la variable nb_operation_credit_depot_M est 34.75766625725239
# la variance de la variable SURFACE_FINANCIERE_M6 est 13219148997.593086
# la variance de la variable nb_ret_carte_Aut_bq_M est 1.170514122277681
# la variance de la variable NB_VIR_AGENCE_6M est 8.032023493707426
# la variance de la variable nb_operation_debit_ep_a_vue_M6 est 2.538623246895596
# la variance de la variable mt_ret_carte_etr_M6 est 2134.166785325281
# la variance de la variable SURFACE_FINANCIERE_ECART_M6 est 1116710411.8512058
# la variance de la variable ENCOURS_CONSO est 80090346.04712057
# la variance de la variable mt_paiement_carte_M est 1046405.0007754391
# la variance de la variable mt_ret_carte_CRCA_M6 est 55754.862546226264
# ...

# %%
for nom in Colonnes_momo :
    plt.hist(data_momo[nom])

    plt.title(nom, fontsize=10)
    plt.show()

# %%
y_report = sv.analyze(data_momo)
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-bffe3748f068> in <module>
#       1 y_report = sv.analyze(data_momo)
# ----> 2 my_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"
#
# NameError: name 'my_report' is not defined

# %%
y_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
def Normalize(x):
    xred = (x - np.mean(x))/np.sqrt(np.var(x))
    return xred

# %%
data_momo_norm = Normalize(data_momo)
